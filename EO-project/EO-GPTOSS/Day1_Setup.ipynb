# %% [markdown]
# # ISRO Multimodal Satellite Imagery Project - Colab Setup
# ## Day 1: Environment Setup & Baseline Testing
#
# This notebook sets up everything you need to run the project in Google Colab.

# %% [markdown]
# ## 1. Check GPU Availability

# %%
import torch
import sys

print(f"Python version: {sys.version}")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
else:
    print("\n⚠️ WARNING: No GPU detected!")
    print("Go to Runtime → Change runtime type → Select GPU")

# %% [markdown]
# ## 2. Install Required Libraries

# %%
# %%capture
# Install transformers and related libraries
# !pip install -q transformers==4.36.0
# !pip install -q accelerate==0.25.0
# !pip install -q peft==0.7.1
# !pip install -q bitsandbytes==0.41.3
# !pip install -q sentencepiece==0.1.99

# Install geospatial libraries (lightweight versions for Colab)
# !pip install -q rasterio==1.3.9
# !pip install -q geopandas==0.14.1

# Install visualization and utilities
# !pip install -q matplotlib seaborn plotly
# !pip install -q scikit-image opencv-python-headless
# !pip install -q tqdm pillow

print("✓ All libraries installed!")

# %% [markdown]
# ## 3. Create Project Directory Structure

# %%
import os
from pathlib import Path

# Create directory structure
base_dir = Path('/content/isro_project')
dirs = [
    'data/raw',
    'data/processed',
    'data/annotations',
    'outputs/visualizations',
    'outputs/predictions',
    'results/baseline',
    'results/multispectral',
    'results/comparisons',
    'models',
    'logs'
]

for d in dirs:
    (base_dir / d).mkdir(parents=True, exist_ok=True)

print("✓ Directory structure created:")
# !tree /content/isro_project -L 2

# %% [markdown]
# ## 4. Mount Google Drive (Optional - for data persistence)

# %%
from google.colab import drive
drive.mount('/content/drive')

# Create project folder in Drive
drive_project = Path('/content/drive/MyDrive/ISRO_Multimodal_Project')
drive_project.mkdir(exist_ok=True)

print(f"✓ Google Drive mounted at: {drive_project}")

# %% [markdown]
# ## 5. Verify All Imports

# %%
# Test all critical imports
import torch
import transformers
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import rasterio
from PIL import Image
from tqdm import tqdm
import json

print("✓ All imports successful!")
print("\nLibrary Versions:")
print(f"  PyTorch: {torch.__version__}")
print(f"  Transformers: {transformers.__version__}")
print(f"  NumPy: {np.__version__}")
print(f"  Rasterio: {rasterio.__version__}")

print("\n" + "="*50)
print("SETUP COMPLETE! Ready to proceed with baseline testing.")
print("="*50)

# %% [markdown]
# ## 6. Quick GPU Memory Test

# %%
if torch.cuda.is_available():
    # Allocate a test tensor to check GPU
    test_tensor = torch.randn(1000, 1000).cuda()
    print(f"✓ GPU memory test successful")
    print(f"  Allocated: {torch.cuda.memory_allocated() / 1024**2:.2f} MB")
    print(f"  Reserved: {torch.cuda.memory_reserved() / 1024**2:.2f} MB")
    del test_tensor
    torch.cuda.empty_cache()
    print(f"  Memory cleared")
else:
    print("⚠️ No GPU available - some operations will be slow")

# %% [markdown]
# ---
# ## Next Steps:
#
# 1. Download Sentinel-2 satellite imagery
# 2. Load BLIP-2 baseline model
# 3. Begin baseline testing
#
# Continue to the next notebook: `Day1_Baseline_Testing.ipynb`
